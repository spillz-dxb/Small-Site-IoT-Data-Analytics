# %% [markdown]
# # Install packages using pip

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install hszinc
# !{sys.executable} -m pip install pyhaystack
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install requests

# %% [markdown]
# # Import modules and start session

# %%
import hszinc
import pyhaystack
from pyhaystack.client.niagara import Niagara4HaystackSession
from pyhaystack.util import filterbuilder as fb
import pandas as pd
import matplotlib.pyplot as plt
import math
from datetime import date, datetime, timedelta
import requests
import json

# Configure pandas options
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

uri = 'http://175.45.115.115'
username = 'admin1'
password = 'Enviroman1'

# uri = 'http://120.151.12.65'
# username = 'dhara'
# password = 'Kakkad123'

session = Niagara4HaystackSession(uri=uri, username=username, password=password, pint=True)

# %% [markdown]
# # Examples

# %% [markdown]
# ## About
# session.about() queries basic information about the server.

# %%
op = session.about()
op.wait()
about = op.result

print(about)
# Out:
# <Grid>
# 	Version: 2.0
# 	Columns:
# 		productUri
# 		tz
# 		moduleName
# 		serverName
# 		productName
# 		haystackVersion
# 		productVersion
# 		moduleVersion
# 		serverTime
# 		moduleUri
# 		serverBootTime
# 	Row    0:
# 	productUri=Uri('http://www.tridium.com/')
# 	tz='Sydney'
# 	moduleName='nhaystack'
# 	serverName='SCP'
# 	productName='Niagara AX'
# 	haystackVersion='2.0'
# 	productVersion='4.3.58.18.1'
# 	moduleVersion='2.0.1'
# 	serverTime=datetime.datetime(2018, 4, 29, 9, 53, 20, 686000, tzinfo=<DstTzInfo 'Australia/Sydney' AEST+10:00:00 STD>)
# 	moduleUri=Uri('https://bitbucket.org/jasondbriggs/nhaystack')
# 	serverBootTime=datetime.datetime(2018, 4, 9, 21, 10, 38, 629000, tzinfo=<DstTzInfo 'Australia/Sydney' AEST+10:00:00 STD>)
# </Grid>

# %% [markdown]
# ## Navigation
# session.nav() lets you navigate the structure of the Project Haystack server.

# %%
nav_id = ''
# nav_id = 'his:/'
# nav_id = 'his:/Bourke_Rd_170'

if nav_id:
    op = session.nav(nav_id=nav_id)
    op.wait()
    nav = op.result
else:
    op = session.nav()
    op.wait()
    nav = op.result

print(nav)

# %% [markdown]
# ## Find Entity
# find_entity expects a filter expression, and performs a read specifying the given string as the filter argument
#
# Parameters: <br/>
# `filter_expr` – The filter expression to search for. <br/>
# `limit` – Optional limit to number of entities retrieved. <br/>
# `single` – Are we expecting a single entity? Defaults to True if ids is not a list. <br/>
# `callback` – Asynchronous result callback.

# %%
filter_expr = 'site'
limit = 5
    
op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

print(result)

# %% [markdown]
# ## Prints the site name and the tags & values for that site

# %%
filter_expr = 'site'
limit = 5

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for site in result.keys():
    print(site + ":")
    el = result[site]
    for tag in el.tags:
        print("\t" + tag + ": " + str(el.tags[tag]))
    print("\n")

# %% [markdown]
# ## Prints the point name and the tags & values within that point

# %%
filter_expr = 'point'
limit = 100

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for point in result.keys():
    print(point + ":")
    el = result[point]
    for tag in el.tags:
        print("\t" + tag + ": " + str(el.tags[tag]))
    print("\n")

# %% [markdown]
# ## Filter for 'his' and 'point'
# Uses a filter expression to read all the points that have a 'his' tag. <br/>

# %%
filter_expr = 'his and point'
limit = 1000

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for key in result.keys():
    print(key)

# %% [markdown]
# ## Reads Historical Data into a Series
# ### Reads the historical data of the given point and returns it as a series.
#
# Parameters: <br/>
# `point` – Haystack ‘point’ entity to read the data from <br/>
# `rng` – Historical read range for the ‘point’ <br/>
# `tz` – Optional timezone to translate timestamps to <br/>
# `series_format` – Optional desired format for the series <br/>

# %%
point = 'S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_SA_Temp'
rng = 'today'
tz = None
series_format = None

# rng = 'yesterday'
# rng = '2018-01-01'
# rng = '2018-01-01, 2018-01-07'

op = session.his_read_series(point, rng, tz=tz, series_format=series_format)
op.wait()
result = op.result

print(result.head())
print(result.tail())

# %% [markdown]
# ## Reads Historical Data into a Grid
# ### Reads the historical data of the given point and returns it as a hszinc.grid.Grid.
#
# Parameters: <br />
# `point` – Haystack ‘point’ entity or ID to read the data from <br />
# `rng` – Historical read range for the ‘point’

# %%
point = 'S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_SA_Temp'
rng = 'today'

op = session.his_read(point, rng)
op.wait()
result = op.result

print(result)

# %% [markdown]
# ## Reads Historical Data into a Dataframe
# ### Reads the historical data of multiple given points and returns them as a dataframe.
#
# Parameters: <br/>
# `columns` – A list of Haystack ‘point’ instances or a dict mapping the column label to the Haystack ‘point’ instance. <br/>
# `rng` – Historical read range for the ‘point’ <br/>
# `tz` – Optional timezone to translate timestamps to <br/>
# `frame_format` – Optional desired format for the data frame

# %%
filter_expr = 'point and his'
limit = 10

columns = []
rng = 'today'
tz = None
frame_format = None

# Reads 10 points to view the history of
op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
columns = op.result

### NOTE: Some of the points return the errror 'java.lang.ArrayIndexOutOfBoundsException: 0' causing this
### cell to fail, comment out the code below to test with working points 

columns = [ 'C.Drivers.NiagaraNetwork.The_Bond_30_LB2.points.BacnetNetwork.B2_S1_Spy_1.LB1_AC_S2_Zone_Temp',  
            'C.Drivers.NiagaraNetwork.The_Bond_30_LB2.points.BacnetNetwork.B2_S1_Spy_1.LB2_AC_S2_Zone_Temp',  
            'C.Drivers.NiagaraNetwork.The_Bond_30_LB2.points.BacnetNetwork.B2_S1_Spy_1.LB1_AC_S1_Zone_Temp']
               
# Reads the history of the points in columns into a dataframe
op = session.his_read_frame(columns, rng=rng, tz=tz, frame_format=frame_format)
op.wait()
result = op.result

print(result)

# %% [markdown]
# # Testing

# %%
filter_expr = 'equip'
limit = 10

op = session.find_entity(filter_expr)
op.wait()
result = op.result

for key in result.keys():
    print(key)

# %%
filter_expr = 'point and his'
limit = 10000

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for point in result.keys():
    print(point + ":")
    el = result[point]
    for tag in el.tags:
        print("\t" + tag + ": " + str(el.tags[tag]))
    print("\n")

# %%
filter_expr = 'point and his'
limit = 10000

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for key in result:
    print(key)
    
# S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_Zone_Temp_SP
# Out:
# S.SCP.Ground_AC_Unit_1.Fan_Enable
# S.SCP.Ground_AC_Unit_1.Zone_Temp
# S.SCP.Ground_AC_Unit_1.Fan_Status
# S.SCP.Ground_AC_Unit_1.Schedule
# S.SCP.Ground_AC_Unit_1.Cmp_Enable
# S.SCP.Ground_AC_Unit_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_2.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_3.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_5.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_5.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_5.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_AC_Unit_5.Supply_Air_Temp
# S.SCP.Floor_1_AC_Unit_1.Fan_Enable
# S.SCP.Floor_1_AC_Unit_1.Zone_Temp
# S.SCP.Floor_1_AC_Unit_1.Rev_Valve
# S.SCP.Floor_1_AC_Unit_1.Cmp_Enable
# S.SCP.Floor_1_AC_Unit_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_2.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_2.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_3.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_3.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_1_AC_Unit_3.Supply_Air_Temp
# S.SCP.FLOOR_1_AC_4.Fan_Enable
# S.SCP.FLOOR_1_AC_4.Zone_Temp
# S.SCP.FLOOR_1_AC_4.Rev_Valve
# S.SCP.FLOOR_1_AC_4.Cmp_Enable
# S.SCP.FLOOR_1_AC_4.Supply_Air_Temp
# S.SCP.floor_2_ac_2.Fan_Enable
# S.SCP.floor_2_ac_2.Zone_Temp
# S.SCP.floor_2_ac_2.Rev_Valve
# S.SCP.floor_2_ac_2.Fan_Status
# S.SCP.floor_2_ac_2.Cmp_Enable
# S.SCP.floor_2_ac_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_3.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_3.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_3.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_4.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_4.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_4.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_2_AC_Unit_4.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_1.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_1.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_1.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_2.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_2.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_3.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_3.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_3.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_4.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_4.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_4.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_4.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_5.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_3_AC_Unit_5.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_1.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_1.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_1.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_2.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_2.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_3.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_3.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_4.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_4.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_4.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Floor_4_AC_Unit_4.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Stuido_2.Comp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Stuido_2.RV
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Stuido_2.Rm_Sensor
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Stuido_2.SAT_AC_1_6
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Foyer.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Foyer.Comp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Foyer.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Foyer.Rm_Sensor
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Gym_West.Foyer.RV
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Level_4_Coolroom.Level_4_Coolroom
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Cmp_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Rev_Valve
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Fan_Status1
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_184.points.Ground_YOGA_Rm.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Breville.FCUS.FCU_L1_2.OAF.OA_Damper
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Breville.Ventilation_Fans.KEF_GF_S1.Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Breville.Ventilation_Fans.KEF_L1_E1.Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Breville.Link_EDH.EDH_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Breville.Link_EDH.EDH_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_1.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_1.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_1.Ahrs_Running
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_1.CHWV_Output
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_2.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_2.CHWV_Output
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_AHU_2.Ahrs_Running
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_VAV_2_AHU1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_VAV_2_AHU1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_VAV_2_AHU1.Zone_Temp_SE
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_VAV_4_AHU2.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Ground_VAV_4_AHU2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_1.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_1.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_1.CHWV_Output
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_2.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_AHU_2.CHWV_Output
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_1_AHU1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_1_AHU1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_1_AHU1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_2_AHU1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_2_AHU1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_2_AHU1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_4_AHU2.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_4_AHU2.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_4_AHU2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_4_AHU2.Zone_Temp_SE
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_1_VAV_4_AHU2.Room_Temp_SW
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_1_AHU1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_1_AHU1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_1_AHU1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_2_AHU1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_2_AHU1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_2_AHU1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_3_AHU2.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_3_AHU2.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_3_AHU2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_4_AHU2.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_4_AHU2.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Level_2_VAV_4_AHU2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-1.Chiller_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-1.CH_Cmpr_2_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-1.CH_Cmpr_1_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-1.Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-1.Chilled_Water_Pump_1_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-2.Chilled_Water_Pump_2_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-Common.Chiller_Return_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller-Common.Chiller_Supply_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chilled_Water_Pump_1_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chilled_Water_Pump_2_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller_Return_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Chiller_Supply_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Chiller.Lead_CHWP
# C.Drivers.NiagaraNetwork.Bourke_Rd_180.points.Boardroom_AC.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.CRAC_Units.CRAC_1_1.Runtime
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.CRAC_Units.CRAC_1_1.Cooling
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.CRAC_Units.CRAC_1_2.Runtime
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.CRAC_Units.CRAC_1_2.Cooling
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.VRF.FCU_GF_4.Setpoint
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Breville.VRF.FCU_GF_5.Setpoint
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.AHU.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.AHU.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.AHU.CHWV
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.AHU.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.Zone_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.Zone_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.Zone_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Ground_Floor.Zone_4.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.AHU.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.AHU.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.AHU.CHWV
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.AHU.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.Zone_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.Zone_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.Zone_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.EDH
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_1.FCU_8.Fan_Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.AHU.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.AHU.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.AHU.CHWV
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.AHU.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.AHU.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_1.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_1.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_2.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_2.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_3.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_3.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_5.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_5.VAV_Act_Flow
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_5.VAV_DamperPos
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.VAV_6.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.CHWV
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.EDH
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_1.Fan_Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.EDH
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.Fan_Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_2.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.Zone_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.Fan_Status
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.After_Hours
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.Fan_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.EDH
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Level_2.FCU_9.Fan_Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.Chiller_Fault
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.Max_Cool_Demand
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.CH_Enable
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.Chiller_Return_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.Chiller_Supply_Water_Temp
# C.Drivers.NiagaraNetwork.Bourke_Rd_170.points.Chilled_Water_Plant.Chiller_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Basment.Comms_AC_Unit.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Basment.Comms_AC_Unit.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Basment.Power_Meter.MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.Nitrogen_Dioxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.Carbon_Monoxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.AHU_G1.SA_DP
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Ground_Floor.Power_Meter.MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.SA_DP
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.Nitrogen_Dioxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.AHU_MEZ.Carbon_Monoxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Mez_Level.Power_Meter.MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.SA_DP
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.Nitrogen_Dioxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.AHU_L1.Carbon_Monoxide
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_1.Power_Meter.MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_N.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_N.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_N.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_N.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_N.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E1.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E1.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E1.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E1.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E1.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E2.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E2.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E2.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E2.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_E2.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WN.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WN.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WN.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WN.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WN.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_S.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_S.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_S.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_S.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_S.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.Power_Meter.MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.Chw_Flow_Meter.Total_Flow
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.Chw_Flow_Meter.Total-Cool
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.Hw_Flow_Meter.Total_Flow
# C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.Hw_Flow_Meter.Total-Heat
# C.Drivers.NiagaraNetwork.Ski_Center.points.Shut_Off_Valves.InterSki_CHW_Bypass_Valve_V5_1_C4_BO2
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Tank_Temp_Middle_C1_UI2
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Tank_Temp_Top_C1_UI1
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Tank_Return_Temp_To_CH_T11_C1_UI5
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Chiller_Supply_Temp_T2_C1_UI3
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Chiller_Return_Temp_T1_C1_UI4
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Ski_Return_Temp_C4_UI1
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Ski_Supply_Temp_C4_UI2
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.InterSki_CHWP_Outlet_Temp_T7_C3_UI1
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.Tank_Leaving_Water_Header_Temp_T5_C3_UI5
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.InterSki_CHWP_Outlet_Temp_T6_C3_UI2
# C.Drivers.NiagaraNetwork.Ski_Center.points.System_Temps.CHW_Field_Bypass_T8_C4_UI3
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.PCHWP_1.PCHWP_1_Enable_C1_BO1
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.PCHWP_1.PCHWP_1_VSD_C1_AO8
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.PCHWP_1.PCHWP_1_RUN_STS
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.PCHWP_1.PCHWP_1_FAULT
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.Chiller_1.CH1_Enable_C1_BO2
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.Chiller_1.PCHWP_1_FAULT
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.Tank_Water_Level_Sensor_C1_UI6
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.Tank_Make_Up_Water_C4_C05
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chilled_Water_Plant.Chiller_Mode
# C.Drivers.NiagaraNetwork.Ski_Center.points.PCHWP_1_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Supply_Air_Temperature
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Supply_Air_Pressure
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Centre_North_Zone_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.CHWV
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.VSD_Speed
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.VSD_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.EDH_1_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Fan_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Cot_Room_1_EDH_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Cot_Room_2_EDH_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Meeting_Room_EDH_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Cot_Room_1_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Cot_Room_2_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.Meeting_Room_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.OAD
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.RAD
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_2.SAD
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.Supply_Air_Temperature
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.Supply_Air_Pressure
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.Centre_Zone_North_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.Centre_Zone_South_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.CHWV
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.VSD_Speed
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.VSD_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.EDH_1_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.AHU_3.Fan_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.CHWP.Childcare_CHWP_Run_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.CHWP.Childcare_CHWP_VSD_Speed
# C.Drivers.NiagaraNetwork.Ski_Center.points.Child_Care.CHWP.Childcare_CHWP_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.CHWP_3_Run_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.niCHWP_3_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.CHWP_3_VSD_Output
# C.Drivers.NiagaraNetwork.Ski_Center.points.Doody_St_CHWP.CHWP_3_Run_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.Doody_St_CHWP.niCHWP_3_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Doody_St_CHWP.CHWP_3_VSD_Output
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_VSD_Speed_C3_AO8
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_Enable_C3_BO3
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_Status_C3_UI3
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_Fault_C3_UI4
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.Cooling_Calls.Sky_Zone_Cool_Call_1_Cafe
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.Cooling_Calls.Sky_Zone_Cool_Call_3_Party_Check_in
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.Cooling_Calls.Sky_Zone_Cool_Call_2_Recertion_L3
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_Discharge_Pressure
# C.Drivers.NiagaraNetwork.Ski_Center.points.Sky_Zone_SCHWP.SCHWP_1_Flow_Meter
# C.Drivers.NiagaraNetwork.Ski_Center.points.InterSki_SCHWP.SCHWP_4_Discharge_Pressure
# C.Drivers.NiagaraNetwork.Ski_Center.points.InterSki_SCHWP.SCHWP_4_VSD_Speed
# C.Drivers.NiagaraNetwork.Ski_Center.points.InterSki_SCHWP.SCHWP_4_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.InterSki_SCHWP.SCHWP_4_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.New_CHW_Tank_PG.Chiller_Mode
# C.Drivers.NiagaraNetwork.Ski_Center.points.New_CHW_Tank_PG.Outside_Air_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Outside_Air_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02.Chiller_2_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02.Chiller_2_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.CHWP_02.CHWP_2_Status
# C.Drivers.NiagaraNetwork.Ski_Center.points.CHWP_02.CHWP_2_Enable
# C.Drivers.NiagaraNetwork.Ski_Center.points.Lead_Chiller
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.CHW_Return_Temperature
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.CHW_Supply_Temperature
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Outside_Air_Temp
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Active_Power
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_1_Comp_1_Run_H
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_1_Comp_2_Run_H
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_1_Comp_3_Run_H
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_2_Comp_1_Run_H
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_2_Comp_2_Run_H
# C.Drivers.NiagaraNetwork.Ski_Center.points.Chiller_02_HLI.Circuit_2_Comp_3_Run_H
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_1.SA_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_1.Zone_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_2.SA_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_2.Zone_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_2.Fan_Enable
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_2.Run_Status
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_3.SA_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_3.Zone_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_3.Fan_Enable
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_3.Run_Status
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_3.PB
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_4.Zone_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_4.Fan_Enable
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_4.Run_Status
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_4.PB
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_5.SA_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_5.Zone_Temp
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_5.Run_Status
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_5.Fan_Enable
# C.Drivers.NiagaraNetwork.Inter_Ski.points.FCU_5.PB
# C.Drivers.NiagaraNetwork.Inter_Ski.points.AC_1.COMP1~2dC
# C.Drivers.NiagaraNetwork.Inter_Ski.points.AC_1.SF~2dC
# C.Drivers.NiagaraNetwork.Inter_Ski.points.AC_1.REV1~2dC
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_1.Supply_Fan_Status
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_1.Supply_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_2.Supply_Fan_Status
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_2.Supply_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_3.Supply_Fan_Status
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_3.Supply_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4.Supply_Fan_Status
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4.Supply_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.BO_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.BO_Comp_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.BO_Rev_Valve
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.AI_Room_Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.AI_Supply_Temp
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.AV_Cool_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.AV_Heat_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_2.CO_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.BO_Fan_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.BO_Comp_Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.BO_Rev_Valve
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.BI_Fan_Status
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.AI_Room_Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.AI_Supply_Temp
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.AV_Cool_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.AV_Heat_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_5.CO_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_7.GreaterThan.AV_Heat_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.PAC_7.GreaterThan.AV_Cool_SP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.CHWP_3.CHWDP
# C.Drivers.NiagaraNetwork.Doody_St_55.points.TEF_G_01.Dynalight_Dry_Contact
# C.Drivers.NiagaraNetwork.Doody_St_55.points.TEF_G_02.Dynalight_Dry_Contact
# C.Drivers.NiagaraNetwork.Doody_St_55.points.TEF_G_03.Dynalight_Dry_Contact
# C.Drivers.NiagaraNetwork.Doody_St_55.points.TEF_G_04.Dynalight_Dry_Contact
# C.Drivers.NiagaraNetwork.Doody_St_55.points.GEF_G_01.Temp
# C.Drivers.NiagaraNetwork.Doody_St_55.points.GEF_G_02.Temp
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_1.Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_1.Damper
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_1.Temp_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_2.Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_2.Damper
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_4_Zone_2.Temp_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_3_Office_Zone.Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_3_Office_Zone.Damper
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_3_Office_Zone.Temp_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_1_Office_Zone.Temp_1
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_1_Office_Zone.Damper
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AHU_1_Office_Zone.Temp_2
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_01.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_01.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_02.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_02.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_03.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_03.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_03.CO2_Sensor
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_04.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_04.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_05.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_05.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_05.CO2_Sensor
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_06.CO2_Sensor
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_07.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_07.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_08.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_08.After_Hours
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_08.Enable
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_09.OAD
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_09.After_Hours
# C.Drivers.NiagaraNetwork.Doody_St_55.points.AC_G_09.Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Basement.Comms_Room_AC.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Basement.Substation_AC.Fan_Sts
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Basement.Substation_AC.Comp2
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Basement.Substation_AC.Comp3
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Basement.Substation_AC.Supply_Air_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d1.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d1.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d1.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d1.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d1.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d3.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d4.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d5.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d6.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d7.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Stairwell.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-Reception.After_Hrs
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.Window_Louvres.Window_Louvres
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.Fan_Status
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.CHWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.HWV
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.Fan_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.Zone_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.SAT
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Level-1.FCU-WGA~2d2new.Economy_Enabled
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler.Boiler-1.Boiler_1_Return_Temp1
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler.Boiler-1.Boiler_1_Supply_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler.Boiler-2.Boiler_2_Supply_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler.Boiler-2.Boiler_2_Return_Temp1
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.Chiller-1.CH1_Diff_Pressure1
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.Chiller_1_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.Chiller_2_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.CHWP_1_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.CHWP_2_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.CHWP_3_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.CHWP_4_Enable
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.Chiller_1_Amps
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.Common_CHW_Supply_Temp1
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Chiller.CHILLER_AMPS
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Misc.Solar_Supply_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Misc.Solar_Return_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Misc.Solar_Tank_1_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Misc.Solar_Tank_2_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Misc.Power_Meter.Plant_MCSB_KWH
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.CH1_Diff_Pressure
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.CH2_Diff_Pressure
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler_1_Return_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler_1_Supply_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler_2_Supply_Temp
# C.Drivers.NiagaraNetwork.Oriordan_St_93_West.points.Boiler_2_Return_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.SAT
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Zone_1_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Zone_2_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Zone_3_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Fan_Status
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Compressor_1
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Compressor_2
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Heater_1_A
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Heater_1_B
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Heater_2_A
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_1.points.Heater_2_B
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_2.points.Zone_1_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_2.points.Zone_2_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_2.points.Zone_3_Temp
# C.Drivers.BacnetNetwork.Bourke_Rd_170_Rear.EasyIO_170_Rear_BLD_CNT_2.points.Zone_Temp_4
# H.Bourke_Rd_170.Bourke_Rd_170_VAV_2_6_VAV_Act_Flow
# H.Bourke_Rd_170.Bourke_Rd_170_VAV_2_6_VAV_DamperPos
# H.Bourke_Rd_170.Breville_SAF_L1_E1_OA_Damper
# H.Bourke_Rd_180.Bourke_RD_180_CHW_Field_DP
# H.Bourke_Rd_180.Bourke_RD_CHWP_01_VSD_Fault
# H.Bourke_Rd_180.Bourke_RD_CHWP_02_VSD_Fault
# H.Bourke_Rd_180.Breville_OAF_GF_1_OA_Damper
# H.Bourke_Rd_180.Breville_OAF_GF_1_Status
# H.Bourke_Rd_180.Cooling_Call
# H.Bourke_Rd_180.Lvl_1_VAV_4_Zone_Temp_1
# H.Bourke_Rd_184.Bourke_Rd_184_Lvl_4_AC_Unit_3_Zone_Temp
# H.Doody_St_55.AC_GO_6_Enable
# H.Doody_St_55.AHU_01_After_Hrs
# H.Doody_St_55.AHU_02_After_Hrs
# H.Doody_St_55.AHU_03_After_Hrs
# H.Doody_St_55.AHU_04_After_Hrs
# H.Doody_St_55.AuditHistory
# H.Doody_St_55.LogHistory
# H.Inter_Ski.After_Hours_Enable
# H.Inter_Ski.FCU_1_Fan_Enable
# H.Inter_Ski.FCU_1_Run_Status
# H.Inter_Ski.LogHistory
# H.Inter_Ski.Office_AC_Temp
# H.Inter_Ski.Ski_Centre_FCU_4_SA_Temp
# H.Oriordan_St_93_East.G_Mez_1_East_Cooling_Energy
# H.Oriordan_St_93_East.G_Mez_1_East_Total_Flow
# H.Oriordan_St_93_East.Ground_East_After_Hours
# H.Oriordan_St_93_East.Ground_Floor_AHU_Supply_Air_Temp
# H.Oriordan_St_93_East.Level_1_AHU_Supply_Air_Temp
# H.Oriordan_St_93_East.Level_1_East_After_Hours
# H.Oriordan_St_93_East.Mez_AHU_Supply_Air_Temp
# H.Oriordan_St_93_East.Mez_East_After_Hours
# H.Oriordan_St_93_West.AuditHistory
# H.Oriordan_St_93_West.Boiler_1_Enable
# H.Oriordan_St_93_West.Boiler_1_Status
# H.Oriordan_St_93_West.Boiler_2_Enable
# H.Oriordan_St_93_West.Boiler_2_Status
# H.Oriordan_St_93_West.Chiller_1_Capacity
# H.Oriordan_St_93_West.Chiller_1_Return_Temp
# H.Oriordan_St_93_West.Chiller_1_Supply_Temp
# H.Oriordan_St_93_West.Chiller_2_Capacity
# H.Oriordan_St_93_West.Chiller_2_Return_Temp
# H.Oriordan_St_93_West.Chiller_2_Supply_Temp
# H.Oriordan_St_93_West.Common_CHW_Return_Temp
# H.Oriordan_St_93_West.Cooling_Calls_FCU_Foyer
# H.Oriordan_St_93_West.Cooling_Calls_FCU_Office_Centre
# H.Oriordan_St_93_West.Cooling_Calls_FCU_Office_East
# H.Oriordan_St_93_West.Cooling_Calls_FCU_Office_NW
# H.Oriordan_St_93_West.Cooling_Calls_FCU_Office_SW
# H.Oriordan_St_93_West.FCU_Foyer_SAT
# H.Oriordan_St_93_West.FCU_L1WGA1_Fan_Enable
# H.Oriordan_St_93_West.FCU_L1WGA1_Fan_Status
# H.Oriordan_St_93_West.FCU_Office_CS_SAT
# H.Oriordan_St_93_West.FCU_Office_NW_SAT
# H.Oriordan_St_93_West.FCU_Office_SE_SAT
# H.Oriordan_St_93_West.FCU_Office_SW_SAT
# H.Oriordan_St_93_West.Ground_CHW_Cooling_Energy
# H.Oriordan_St_93_West.Ground_CHW_Total_Flow
# H.Oriordan_St_93_West.Ground_Floor_Cooling-Totalized_KWHs
# H.Oriordan_St_93_West.Ground_Floor_Heating-Totalized_KWHs
# H.Oriordan_St_93_West.Ground_Floor_MCSB_KWH
# H.Oriordan_St_93_West.Ground_HW_Heating_Energy
# H.Oriordan_St_93_West.Ground_HW_Total_Flow
# H.Oriordan_St_93_West.Heating_Calls_FCU_Foyer
# H.Oriordan_St_93_West.Heating_Calls_FCU_Office_Centre
# H.Oriordan_St_93_West.Heating_Calls_FCU_Office_East
# H.Oriordan_St_93_West.Heating_Calls_FCU_Office_NW
# H.Oriordan_St_93_West.Heating_Calls_FCU_Office_SW
# H.Oriordan_St_93_West.L1_Cooling_Energy
# H.Oriordan_St_93_West.L1_Cooling_Total_Flow
# H.Oriordan_St_93_West.L1_Heating_Energy
# H.Oriordan_St_93_West.L1_Heating_Total_Flow_Energy
# H.Oriordan_St_93_West.L1_West_CHW_Total_Flow
# H.Oriordan_St_93_West.L1_West_Cooling_Energy
# H.Oriordan_St_93_West.L1_West_HW_Total_Flow
# H.Oriordan_St_93_West.L1_West_Heating_Energy
# H.Oriordan_St_93_West.L2_CHW_Flow_Meter_HW_Energy
# H.Oriordan_St_93_West.L2_CHW_Flow_Meter_HW_Energy_Partial
# H.Oriordan_St_93_West.Level_1_Cooling-Totalized_KWHs
# H.Oriordan_St_93_West.Level_1_Heating-Totalized_KWHs
# H.Oriordan_St_93_West.Level_1_MCSB_KWH
# H.Oriordan_St_93_West.LogHistory
# H.Oriordan_St_93_West.Nissan_FCU_Center_Fan_Status
# H.Oriordan_St_93_West.Nissan_FCU_East_Fan_Status
# H.Oriordan_St_93_West.Nissan_FCU_Foyer_Fan_Status
# H.Oriordan_St_93_West.Nissan_FCU_NW_Fan_Status
# H.Oriordan_St_93_West.Nissan_FCU_SW_Fan_Status
# H.Oriordan_St_93_West.Outside_Air_Humidity
# H.Oriordan_St_93_West.Outside_Air_Temp
# H.Oriordan_St_93_West.Plant_Coooling_Call
# H.Oriordan_St_93_West.Pump_STS_To_CH1
# H.Oriordan_St_93_West.Status_CHWP_1
# H.Oriordan_St_93_West.Status_CHWP_2
# H.Oriordan_St_93_West.Status_CHWP_3
# H.Oriordan_St_93_West.Status_CHWP_4
# H.Oriordan_St_93_West.Status_HWP_1
# H.Oriordan_St_93_West.Status_HWP_2
# H.Oriordan_St_93_West.Status_HWP_3
# H.Oriordan_St_93_West.Status_HWP_4
# H.Oriordan_St_93_West.Sub_Station_AC_Comp_1_Enable
# H.Oriordan_St_93_West.Sub_Station_AC_Comp_2_Enable
# H.Oriordan_St_93_West.Sub_Station_AC_Fan_Sts
# H.Oriordan_St_93_West.Sub_Station_AC_Supply_Air_Temp
# H.Oriordan_St_93_West.Switch_Rm_FCU_Room_Temp
# H.Oriordan_St_93_West.Switch_Rm_FCU_SA_Temp
# H.SCP.AuditHistory
# H.SCP.DeviceNetworkJobHistoryRecord
# H.SCP.DeviceStepHistoryRecord
# H.SCP.LogHistory
# H.SCP.NetworkStepHistoryRecord
# H.Ski_Center.AuditHistory
# H.Ski_Center.CHWP_1_Flow_To_CH1_C2_CO5
# H.Ski_Center.InterSki_CHW_Field_Return_To_Chiller_V4_2
# H.Ski_Center.InterSki_CHW_Field_Return_To_Tank_V4_1
# H.Ski_Center.InterSki_CHW_Isolation_Valve_V2_1_C4_BO1
# H.Ski_Center.InterSki_Supply_Water_Valve_V1_2_C3_BO2
# H.Ski_Center.Inter_Ski_Cooling-Totalized_KWHs
# H.Ski_Center.LogHistory
# H.Ski_Center.SCHWP_1_After_Hours
# H.Ski_Center.SCHWP_2_After_Hours
# H.Ski_Center.SCHWP_2_DP
# H.Ski_Center.SCHWP_3_After_Hours
# H.Ski_Center.SCHWP_4_After_Hours
# H.Ski_Center.Tank_Leaving_Water_Header_Valve_V1_1_C3_BO1
# H.Ski_Center.Tank_Return_To_CH_Valve_C1_C05
# H.Ski_Center.Tank_Supply_Valve_V1_3_C1_CO4

# %%
filter_expr = 'point and his and equipRef'
limit = 100

op = session.find_entity(filter_expr=filter_expr, limit=limit)
op.wait()
result = op.result

for key in result:
    equipRef = result[key].tags['equipRef']
    if(str(equipRef) == '@S.The_Bond_30.G_WCPAC_1'):
        print(key)

# %% [markdown]
# ### Compare data from S.The_Bond_30.G_WCPAC_1

# %%
# Fetches the zone temp set point, the run status, and the return air temp for the specified date range. 

columns = [ 'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Zone_Temp_SP',
            'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St',
            'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_RA_Temp']

rng = '2018-02-01, 2018-02-07'

op = session.his_read_frame(columns, rng)
op.wait()
result = op.result

result.head()

# %%
# The timestamps for each column don't match up so the data is re-sampled at 15 minute intervals.
# the run status is a bool value that is only recorded when changed, therefore we must fill in the correct 
# value for each time stamp using the fillna method.

resampledResult = result.resample('15T').agg({
    'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Zone_Temp_SP': 'mean',
    'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_RA_Temp':'mean',
    'S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St':'last'
})

resampledResult['S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St'].fillna(method='ffill', inplace=True)

# Replaces the remaining NaNs with False, in this case this is correct 
resampledResult['S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St'].fillna(False, inplace=True)

# Alternatively, we could just drop the remaining NaNs
# resampledResult.dropna(inplace=True)

resampledResult.head()

# %%
# The re-sampled data is plotted on a graph.
# The run status is converted to a int and the SP temp is added to it so we can see when it is on and off
# compared to the other temps

plotResults = resampledResult.copy()
plotResults['S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St'] = plotResults['S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Run_St'].astype(int) + plotResults['S.The_Bond_30.G_WCPAC_1.G_WCPAC_1_Zone_Temp_SP']
plotResults.plot(figsize=(16, 8))

# %% [markdown]
# ### Compare data from S.The_Bond_30.G_WCPAC_3 and historical weather data

# %%
# Fetches the zone temp set point, the supply air temp, and the return air temp for the specified date range. 

columns = [ 'S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_Zone_Temp_SP',
            'S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_SA_Temp',
            'S.The_Bond_30.G_WCPAC_3.G_WCPAC_3_RA_Temp']

rng = '2018-01-27, 2018-02-10'

op = session.his_read_frame(columns, rng)
op.wait()
result = op.result

result.head()

# %%
# The timestamps for each column don't match up so the data is re-sampled at 15 minute intervals.

resampledResult = result.resample('15T').mean()
resampledResult.head()

# %%
# Initial plot of the temps for the specified date range

resampledResult.plot(figsize=(16, 8))

# %%
# Using the Dark Sky API we can retrieve historical weather data for the site.
# We construct a url from the latitude and longitude of the site and the specified date ranges.

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
        
lat = -33.8618
lon = 151.2031
api_key = '801e57289de2da50cf9e496e4c823e6c'

start_date = datetime(2018,1,27,0,0)
end_date = datetime(2018,2,10,0,0)

weatherData = pd.DataFrame()

# For the given dates we loop through each day and make an API request to retrieve the historical weather data
# for that day. Each days data is appended to the weatherData dataframe. 
for single_date in daterange(start_date, end_date):
    time = int(single_date.timestamp())
    url = 'https://api.darksky.net/forecast/' + api_key + '/' + str(lat) + ',' + str(lon) + ',' + str(time) + '?units=si'
    r = requests.get(url)
    json = r.json()
    weatherData = weatherData.append(pd.DataFrame(json['hourly']['data']), ignore_index=True)

weatherData.head()

# %%
# The time column is converted from unix time to a datatime object.

weatherData['time'] = pd.to_datetime(weatherData['time'], unit='s', utc=True)

# %%
# Discard other columns leaving the time and temperature columns and set the index as the timestamp.
# Upsample the weather data from every hour to every 15 minutes and interpolate the missing values.

weatherData = weatherData[['time', 'temperature']]
weatherData = weatherData.set_index('time')
weatherData = weatherData.resample('15T').mean()
weatherData = weatherData.interpolate(method='linear')
weatherData.head()

# %%
# Merge the data pulled from Niagara and the historical weather on the indexes (timestamps), convert
# the timezone to Sydney, and rename the columns.

final = resampledResult.merge(weatherData, left_index=True, right_index=True)
final = final.tz_convert('Australia/Sydney')
final.columns = ['SA_Temp', 'Zone_Temp_SP', 'RA_Temp', 'Hist_Weather']
final.head()

# %%
# Plot the Niagara data against the historical weather data.

final.plot(figsize=(16, 8))

# %%
# 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.Zone_Temp'
# 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.SAT'
# 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.Fan_Status'
# 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.CHWV'
# 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.HWV'


point = 'C.Drivers.NiagaraNetwork.Oriordan_St_93_East.points.Level_2.FCU_L2_WS.Fan_Status'
# rng = 'today'
tz = None
series_format = None

# rng = 'yesterday'
# rng = '2018-01-01'
# rng = '2018-01-01, 2018-01-07'
rng = '2018-03-01, 2018-03-08'

op = session.his_read_series(point, rng, tz=tz, series_format=series_format)
op.wait()
result = op.result

print(result.to_json())
# Out:
# {"1519844056336":true,"1519887266730":false,"1519930458858":true,"1519973654511":false,"1520189651990":true,"1520232850803":false,"1520276044759":true,"1520319609869":false,"1520362814055":true,"1520406011280":false,"1520449210593":true,"1520492900895":false}
